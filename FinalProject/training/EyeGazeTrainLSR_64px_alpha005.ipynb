# %%
import sys
#!{sys.executable} -m pip install -q "tensorflow==2.15.1" "tensorflow-model-optimization==0.8.0" "scikit-learn==1.4.2" "pandas==2.2.2" "matplotlib==3.8.4"

# !pip install tensorflow-model-optimization
print("Packages Installed")
# Out:
# Collecting tensorflow-model-optimization
#   Downloading tensorflow_model_optimization-0.8.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (2.0.2)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.16.3)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (0.1.10)
# Collecting mock (from tensorflow-model-optimization)
#   Downloading mock-5.2.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (26.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (2.2.2)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /usr/local/lib/python3.12/dist-packages (from tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (4.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (1.82.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.1.2)
# Downloading tensorflow_model_optimization-0.8.1-py2.py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 4.3 MB/s eta 0:00:00
# Downloading mock-5.2.0-py3-none-any.whl (31 kB)
# Installing collected packages: mock, tensorflow-model-optimization
# Successfully installed mock-5.2.0 tensorflow-model-optimization-0.8.1
# Packages Installed

# %%
import os
import math
import zipfile
import random
import urllib.request
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_model_optimization as tfmot

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow import keras
from tensorflow.keras import layers

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("Python executable:", os.sys.executable)
print("TensorFlow version:", tf.__version__)
print("TF-MOT version:", tfmot.__version__)
# Out:
# Python executable: /usr/bin/python3
# TensorFlow version: 2.20.0
# TF-MOT version: 0.8.1

# %%
from google.colab import drive
import zipfile
import os
import shutil # Import shutil for directory operations

mount_point = '/content/drive'

# --- Robust Mounting Logic ---
if os.path.exists(mount_point):
    if os.path.isdir(mount_point):
        # Check if the directory is not empty and is NOT currently a mounted filesystem
        # (i.e., it might contain leftover files that are not part of an active mount)
        if os.listdir(mount_point) and not os.path.ismount(mount_point):
            print(f"Mount point '{mount_point}' exists and is not empty. Clearing contents before mounting...")
            for item in os.listdir(mount_point):
                item_path = os.path.join(mount_point, item)
                try:
                    if os.path.isfile(item_path) or os.path.islink(item_path):
                        os.remove(item_path)
                    elif os.path.isdir(item_path):
                        shutil.rmtree(item_path)
                except Exception as e:
                    print(f"Warning: Could not fully clean {item_path}: {e}")
            print(f"Contents of '{mount_point}' cleared.")
        elif os.path.ismount(mount_point):
            print("Google Drive is already mounted and appears clean. Proceeding with remount (if needed).")
        else: # Directory exists and is empty
            print(f"Mount point '{mount_point}' exists and is empty. Proceeding.")
    else: # /content/drive exists but is not a directory (e.g., a file or broken symlink)
        print(f"Warning: '{mount_point}' exists but is not a directory. Removing and recreating it.")
        os.remove(mount_point) # Remove the non-directory item
        os.makedirs(mount_point)
else: # /content/drive does not exist
    os.makedirs(mount_point)
    print(f"Mount point '{mount_point}' created.")

print("Attempting to mount Google Drive...")
# force_remount=True will handle cases where it was previously mounted by Colab
# and will re-attempt to mount even if the directory was empty before.
drive.mount(mount_point, force_remount=True)
# --- End of Robust Mounting Logic ---

zip_path = '/content/drive/MyDrive/KaggleGazeCapture/eye_gaze_train_lsr.zip'
extract_path = '/content/eye_gaze_train_lsr/'

# Check if the extract_path does not exist or is empty
if not os.path.exists(extract_path) or not os.listdir(extract_path):
    print(f"Dataset not found locally or is empty. Extracting from Drive...")
    os.makedirs(extract_path, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("Extraction complete!")
    # Verification after extraction
    if os.path.exists(extract_path) and os.listdir(extract_path):
        print(f"Verification: '{extract_path}' exists and contains {len(os.listdir(extract_path))} items.")
    else:
        print(f"Verification: Extraction seems to have failed. '{extract_path}' is either missing or empty.")
else:
    print("Dataset directory already exists and contains data.")
    # Verification if directory already exists and contains data
    if os.path.exists(extract_path) and os.listdir(extract_path):
        print(f"Verification: '{extract_path}' already exists and contains {len(os.listdir(extract_path))} items.")
    else:
        print(f"Verification: '{extract_path}' exists but is empty. This condition should not be reached with the updated logic, but checking just in case.")
# Out:
# Mount point '/content/drive' created.
# Attempting to mount Google Drive...
# Mounted at /content/drive
# Dataset not found locally or is empty. Extracting from Drive...
# Extraction complete!
# Verification: '/content/eye_gaze_train_lsr/' exists and contains 2 items.

# %%
IMAGE_SIZE = 64
BATCH_SIZE = 32
ALPHA = 0.05

train_dir = extract_path + '/eye_gaze_train_lsr/train/'
test_dir = extract_path + '/eye_gaze_train_lsr/test/'


train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    color_mode='grayscale',
    interpolation='lanczos3',
    batch_size=None # Load unbatched images initially
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    shuffle=False,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    color_mode='grayscale',
    interpolation='lanczos3',
    batch_size=None # Load unbatched images initially
)
# Out:
# Found 173886 files belonging to 3 classes.
# Found 32233 files belonging to 3 classes.

# %%
# 1. Check tensor shapes and data types
print("--- Dataset Element Specifications ---")
print("Train Dataset Spec:", train_dataset.element_spec)
print("Test Dataset Spec: ", test_dataset.element_spec)

# 2. Inspect class names and total counts
class_names = train_dataset.class_names
print(f"\n--- Class Information ---")
print(f"Total Classes ({len(class_names)}): {class_names}")
# Out:
# --- Dataset Element Specifications ---
# Train Dataset Spec: (TensorSpec(shape=(64, 64, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))
# Test Dataset Spec:  (TensorSpec(shape=(64, 64, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))
#
# --- Class Information ---
# Total Classes (3): ['left', 'right', 'straight']

# %%
# Function to count samples per class in a dataset
def count_samples_per_class(dataset, class_names):
    class_counts = np.zeros(len(class_names), dtype=int)
    for _, labels in dataset:
        unique_labels, counts = np.unique(labels.numpy(), return_counts=True)
        for label, count in zip(unique_labels, counts):
            class_counts[label] += count

    print("\n--- Sample Counts per Class ---")
    for i, count in enumerate(class_counts):
        print(f"Class '{class_names[i]}': {count} samples")
    return class_counts


print("\n--- Training Dataset Class Counts ---")
train_class_counts = count_samples_per_class(train_dataset, class_names)

print("\n--- Test Dataset Class Counts ---")
test_class_counts = count_samples_per_class(test_dataset, class_names)
# Out:
# --- Training Dataset Class Counts ---
#
# --- Sample Counts per Class ---
# Class 'left': 49839 samples
# Class 'right': 53019 samples
# Class 'straight': 71028 samples
#
# --- Test Dataset Class Counts ---
#
# --- Sample Counts per Class ---
# Class 'left': 8923 samples
# Class 'right': 9529 samples
# Class 'straight': 13781 samples

# %%
INPUT_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 1)

def augment_image(image, label):
    # This function now receives a single image (3-D tensor: H, W, C)
    resize_factor = tf.random.uniform([], minval=1.0, maxval=1.2, dtype=tf.float32)
    new_height = tf.cast(resize_factor * INPUT_SHAPE[0], tf.int32)
    new_width = tf.cast(resize_factor * INPUT_SHAPE[1], tf.int32)

    # tf.image.resize_with_crop_or_pad now correctly receives 3-D images
    image = tf.image.resize_with_crop_or_pad(image, new_height, new_width)

    # tf.image.random_crop now correctly receives 3-D images
    image = tf.image.random_crop(image, size=INPUT_SHAPE)

    # tf.image.random_brightness supports N-D images where N >= 3, so it works directly on 3-D
    image = tf.image.random_brightness(image, max_delta=0.2)
    return image, label

def normalize_images(image, label):
    # This function now receives a single image (3-D tensor: H, W, C)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

AUTOTUNE = tf.data.AUTOTUNE # Keep AUTOTUNE defined here

# %% [markdown]
# ### Preparing separate training and validation datasets
#
# Since `validation_split` does not work directly on `tf.data.Dataset` objects, we need to manually split our `train_dataset` into separate training and validation datasets. We'll use 80% for training and 20% for validation, matching the `validation_split=0.2` you intended.

# %% [markdown]
# Now, let's apply the augmentation to the training dataset. It's important to apply augmentation only to the training set, not the validation or test sets, to avoid data leakage and ensure a realistic evaluation of the model's performance on unseen data.

# %%
# Determine the total number of samples from the unbatched training dataset
DATASET_SIZE = tf.data.experimental.cardinality(train_dataset).numpy()
val_size_samples = int(0.2 * DATASET_SIZE) # 20% for validation, in terms of samples

# Split the unbatched train_dataset into unbatched training and validation sets
val_ds_unbatched = train_dataset.take(val_size_samples)
train_ds_unbatched = train_dataset.skip(val_size_samples)

# Apply augmentation to the UNBATCHED training dataset
train_ds_aug = train_ds_unbatched.map(augment_image, num_parallel_calls=AUTOTUNE)

# Apply normalization to all datasets (augmented training, validation, and test)
train_ds = train_ds_aug.map(normalize_images, num_parallel_calls=AUTOTUNE)
val_ds = val_ds_unbatched.map(normalize_images, num_parallel_calls=AUTOTUNE)
test_ds = test_dataset.map(normalize_images, num_parallel_calls=AUTOTUNE) # Renamed for consistency

# Batch and prefetch all final datasets for efficient training
train_ds = train_ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

print(f"Original unbatched train_dataset samples: {DATASET_SIZE}")
print(f"Validation samples: {tf.data.experimental.cardinality(val_ds_unbatched).numpy()}")
print(f"Augmented training samples: {tf.data.experimental.cardinality(train_ds_unbatched).numpy()}")

print(f"\nFinal batched training_dataset batches: {tf.data.experimental.cardinality(train_ds).numpy()}")
print(f"Final batched validation_dataset batches: {tf.data.experimental.cardinality(val_ds).numpy()}")
print(f"Final batched test_dataset batches: {tf.data.experimental.cardinality(test_ds).numpy()}")
# Out:
# Original unbatched train_dataset samples: 173886
# Validation samples: 34777
# Augmented training samples: 139109
#
# Final batched training_dataset batches: 4348
# Final batched validation_dataset batches: 1087
# Final batched test_dataset batches: 1008

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input

# Get the number of classes from class_names
num_classes = len(class_names)

# Create the base MobileNetV2 model with pre-trained weights
# include_top=False to remove the classification layer of the pre-trained model
# input_shape should match IMAGE_SIZE and color_mode (grayscale means 1 channel)
base_model = MobileNetV2(
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 1),
    alpha=ALPHA,
    include_top=False,
    weights=None,
)

inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 1))
x = base_model(inputs)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.1)(x)
outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs, name="eye_gaze_model_lsr_64px")
model.build((None, IMAGE_SIZE, IMAGE_SIZE, 1))


model.summary()
# Out:
# Model: "eye_gaze_model_lsr_64px"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_0.05_64             │ (None, 2, 2, 1280)     │        52,176 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         3,843 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,019 (218.82 KB)
#  Trainable params: 50,067 (195.57 KB)
#  Non-trainable params: 5,952 (23.25 KB)

# %%
model.compile(
    optimizer="adam",
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=5,
        restore_best_weights=True
    )
]


# Train the model
# You might want to adjust epochs based on dataset size and convergence
history = model.fit(
    train_ds, # Use the new training dataset
    epochs=40,
    validation_data=val_ds, # Pass the separate validation dataset
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 327s 57ms/step - accuracy: 0.4622 - loss: 1.0234 - val_accuracy: 0.4644 - val_loss: 1.0378
# Epoch 2/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 228s 47ms/step - accuracy: 0.6279 - loss: 0.8099 - val_accuracy: 0.6162 - val_loss: 0.8952
# Epoch 3/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 220s 45ms/step - accuracy: 0.6687 - loss: 0.7396 - val_accuracy: 0.6644 - val_loss: 0.7609
# Epoch 4/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 223s 46ms/step - accuracy: 0.6941 - loss: 0.6855 - val_accuracy: 0.7061 - val_loss: 0.6880
# Epoch 5/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 239s 49ms/step - accuracy: 0.7218 - loss: 0.6266 - val_accuracy: 0.7345 - val_loss: 0.6149
# Epoch 6/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 247s 46ms/step - accuracy: 0.7439 - loss: 0.5827 - val_accuracy: 0.7565 - val_loss: 0.5574
# Epoch 7/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 257s 45ms/step - accuracy: 0.7585 - loss: 0.5545 - val_accuracy: 0.7306 - val_loss: 0.6362
# Epoch 8/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 243s 51ms/step - accuracy: 0.7662 - loss: 0.5348 - val_accuracy: 0.7623 - val_loss: 0.5500
# Epoch 9/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 265s 51ms/step - accuracy: 0.7732 - loss: 0.5192 - val_accuracy: 0.7808 - val_loss: 0.5129
# Epoch 10/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 236s 49ms/step - accuracy: 0.7793 - loss: 0.5073 - val_accuracy: 0.7763 - val_loss: 0.5167
# Epoch 11/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 221s 45ms/step - accuracy: 0.7873 - loss: 0.4918 - val_accuracy: 0.7677 - val_loss: 0.5330
# Epoch 12/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 226s 46ms/step - accuracy: 0.7909 - loss: 0.4820 - val_accuracy: 0.7978 - val_loss: 0.4642
# Epoch 13/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 234s 48ms/step - accuracy: 0.7959 - loss: 0.4723 - val_accuracy: 0.7917 - val_loss: 0.4695
# Epoch 14/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 238s 49ms/step - accuracy: 0.7991 - loss: 0.4661 - val_accuracy: 0.7820 - val_loss: 0.5035
# Epoch 15/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 261s 49ms/step - accuracy: 0.8027 - loss: 0.4590 - val_accuracy: 0.7947 - val_loss: 0.4769
# Epoch 16/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 233s 48ms/step - accuracy: 0.8039 - loss: 0.4550 - val_accuracy: 0.7809 - val_loss: 0.5182
# Epoch 17/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 229s 47ms/step - accuracy: 0.8063 - loss: 0.4480 - val_accuracy: 0.8099 - val_loss: 0.4384
# Epoch 18/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 228s 47ms/step - accuracy: 0.8094 - loss: 0.4444 - val_accuracy: 0.8067 - val_loss: 0.4495
# Epoch 19/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 231s 47ms/step - accuracy: 0.8107 - loss: 0.4407 - val_accuracy: 0.8172 - val_loss: 0.4294
# Epoch 20/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 225s 46ms/step - accuracy: 0.8132 - loss: 0.4342 - val_accuracy: 0.8069 - val_loss: 0.4576
# Epoch 21/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 260s 46ms/step - accuracy: 0.8152 - loss: 0.4297 - val_accuracy: 0.8180 - val_loss: 0.4298
# Epoch 22/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 257s 45ms/step - accuracy: 0.8165 - loss: 0.4271 - val_accuracy: 0.8104 - val_loss: 0.4501
# Epoch 23/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 260s 44ms/step - accuracy: 0.8176 - loss: 0.4249 - val_accuracy: 0.8083 - val_loss: 0.4444
# Epoch 24/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 235s 48ms/step - accuracy: 0.8189 - loss: 0.4208 - val_accuracy: 0.8199 - val_loss: 0.4191
# Epoch 25/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 233s 48ms/step - accuracy: 0.8198 - loss: 0.4188 - val_accuracy: 0.8177 - val_loss: 0.4242
# Epoch 26/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 258s 48ms/step - accuracy: 0.8217 - loss: 0.4154 - val_accuracy: 0.8033 - val_loss: 0.4619
# Epoch 27/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 226s 46ms/step - accuracy: 0.8238 - loss: 0.4116 - val_accuracy: 0.8194 - val_loss: 0.4182
# Epoch 28/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 226s 46ms/step - accuracy: 0.8240 - loss: 0.4111 - val_accuracy: 0.8179 - val_loss: 0.4242
# Epoch 29/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 221s 45ms/step - accuracy: 0.8262 - loss: 0.4074 - val_accuracy: 0.8215 - val_loss: 0.4118
# Epoch 30/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 225s 46ms/step - accuracy: 0.8266 - loss: 0.4059 - val_accuracy: 0.8145 - val_loss: 0.4350
# Epoch 31/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 227s 47ms/step - accuracy: 0.8271 - loss: 0.4029 - val_accuracy: 0.8272 - val_loss: 0.4081
# Epoch 32/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 227s 46ms/step - accuracy: 0.8285 - loss: 0.4006 - val_accuracy: 0.8261 - val_loss: 0.4032
# Epoch 33/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 276s 50ms/step - accuracy: 0.8282 - loss: 0.3997 - val_accuracy: 0.8316 - val_loss: 0.3945
# Epoch 34/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 234s 48ms/step - accuracy: 0.8299 - loss: 0.3971 - val_accuracy: 0.8299 - val_loss: 0.4000
# Epoch 35/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 251s 52ms/step - accuracy: 0.8312 - loss: 0.3951 - val_accuracy: 0.8366 - val_loss: 0.3769
# Epoch 36/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 244s 50ms/step - accuracy: 0.8319 - loss: 0.3924 - val_accuracy: 0.8244 - val_loss: 0.4164
# Epoch 37/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 241s 50ms/step - accuracy: 0.8321 - loss: 0.3929 - val_accuracy: 0.8351 - val_loss: 0.3866
# Epoch 38/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 240s 49ms/step - accuracy: 0.8341 - loss: 0.3907 - val_accuracy: 0.8321 - val_loss: 0.3908
# Epoch 39/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 236s 49ms/step - accuracy: 0.8335 - loss: 0.3897 - val_accuracy: 0.8358 - val_loss: 0.3831
# Epoch 40/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 239s 49ms/step - accuracy: 0.8343 - loss: 0.3877 - val_accuracy: 0.8413 - val_loss: 0.3691

# %%
import matplotlib.pyplot as plt

# Plot training history (accuracy and loss)
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.show()

# %%
import numpy as np

# Extract all images and labels from the test_dataset
all_test_images = []
all_test_labels = []

for images, labels in test_ds:
    all_test_images.append(images.numpy())
    all_test_labels.append(labels.numpy())

X_test = np.vstack(all_test_images)
y_test = np.concatenate(all_test_labels)

print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_test: (32233, 64, 64, 1)
# Shape of y_test: (32233,)

# %%
# X_test will now be correctly shaped, so no explicit reshape is needed here.
# Make predictions on the extracted test data
probs = model.predict(X_test, verbose=1)
preds = np.argmax(probs, axis=1)

# Calculate accuracy
test_acc = accuracy_score(y_test, preds)

print(f"\nTest Accuracy: {test_acc:.4f}\n")

# Generate and print classification report
print("Classification Report:")
print(classification_report(y_test, preds, target_names=class_names, digits=4))

# Plot confusion matrix
disp = ConfusionMatrixDisplay(
    confusion_matrix=confusion_matrix(y_test, preds),
    display_labels=class_names
)

fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, xticks_rotation=45, cmap="Blues", colorbar=False)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 1008/1008 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step
#
# Test Accuracy: 0.7002
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         left     0.7925    0.6285    0.7010      8923
#        right     0.7166    0.7141    0.7154      9529
#     straight     0.6484    0.7369    0.6898     13781
#
#     accuracy                         0.7002     32233
#    macro avg     0.7192    0.6932    0.7021     32233
# weighted avg     0.7085    0.7002    0.7005     32233

# %%
import os

# Define the directory to save the model in Google Drive
save_dir = '/content/drive/MyDrive/saved_models'
model_name = 'eye_gaze_lsr_mobilenetv2_64px_alpha005.keras'
model_path = os.path.join(save_dir, model_name)

# Create the directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Save the entire model in the TensorFlow SavedModel format
# This includes: the architecture, the weights, and the training configuration (optimizer, loss, metrics)
# For TensorFlow SavedModel format in Keras 3, use model.export()
model.save(model_path)

print(f"Model saved successfully to: {model_path}")
# Out:
# Model saved successfully to: /content/drive/MyDrive/saved_models/eye_gaze_lsr_mobilenetv2_64px_alpha005.keras

# %%
from pathlib import Path

def make_representative_data_gen(batched_dataset, max_samples=7000):
    representative_images = []
    for batch_images, _ in batched_dataset.take(max_samples // BATCH_SIZE + 1):
        for image in batch_images:
            if len(representative_images) < max_samples:
                representative_images.append(image.numpy())
            else:
                break
        if len(representative_images) >= max_samples:
            break

    def generator():
        for img in representative_images:
            sample = np.expand_dims(img, axis=0).astype(np.float32)  # add batch dim -> (1,H,W,C)
            yield [sample]

    return generator

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # no EXPERIMENTAL_SPARSITY - nothing pruned here
converter.representative_dataset = make_representative_data_gen(train_ds)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()
tflite_path = Path(f"{save_dir}/eye_gaze_lsr_mobilenetv2_64px_alpha005_ptq.tflite")
tflite_path.write_bytes(tflite_model)
print(f"Saved {tflite_path.name}: {tflite_path.stat().st_size / 1024:.2f} KB")
# Out:
# Saved artifact at '/tmp/tmp32e2nbd3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 1), dtype=tf.float32, name='keras_tensor_156')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   137451041396816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548224528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548226064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548224144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548224912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548225872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548225680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548231632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548230096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548231440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450548231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554230352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554230544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554229776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554229200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554229008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554230160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554229968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554229584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554231504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554230928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554231120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554231312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554228816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554232464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554232848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554233040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554232080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554232656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554233616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554234000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554234192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554233232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554233808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554234768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554232272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554234384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554234576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554231696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554235728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554235152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554235344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554235536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554231888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554236688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554236112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554236304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554236496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554233424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554237648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554237072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554237264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554237456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554234960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554238608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554238032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554238224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554238416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554235920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554239568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554238992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554239184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554239376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554236880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554240528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554239952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554240144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554240336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554237840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554241488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554240912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554241104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554241296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554238800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554242448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554241872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554242064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554242256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554239760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554243408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554242832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554243024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554243216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554240720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554244368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554243792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554243984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554244560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554244944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554243600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554242640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540451024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554244752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450554241680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540450064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540450448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540450640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540450832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540451984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540451408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540451600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540451792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540449872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540452944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540452368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540452560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540452752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540450256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540453904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540453328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540453520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540453712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540451216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540454864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540454288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540454480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540454672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540452176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540455824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540455248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540455440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540455632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540453136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540456784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540456208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540456400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540456592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540454096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540457744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540457168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540457360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540457552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540455056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540458704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540458128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540458320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540458512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540456016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540459664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540459088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540459280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540459472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540456976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540460624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540460048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540460240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540460432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540457936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540461584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540461008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540461200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540461392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540458896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540462544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540461968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540462160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540462352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540459856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540463504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540462928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540463120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540463312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540460816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540464464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540463888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540464080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540464272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540461776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540465424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540464848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540465040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540465616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540466000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540464656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540463696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540465232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546201808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540465808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450540462736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546200848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546201232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546201424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546201616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546202768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546202192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546202384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546202576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546200656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546203728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546203152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546203344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546203536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546201040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546204688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546204112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546204304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546204496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546202000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546205648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546205072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546205264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546205456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546202960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546206608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546206032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546206224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546206416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546203920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546207568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546206992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546207184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546207376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546204880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546208528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546207952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546208144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546208336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546205840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546209488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546208912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546209104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546209296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546206800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546210448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546209872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546210064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546210256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546207760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546211408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546210832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546211024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546211216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546208720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546212368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546211792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546211984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546212176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546209680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546213328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546212752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546212944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546213136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546210640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546214288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546213520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137450546214096: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Saved eye_gaze_lsr_mobilenetv2_64px_alpha005_ptq.tflite: 168.39 KB

# %% [markdown]
# You can then load this H5 file using `tf.keras.models.load_model()` and proceed with quantization-aware training or post-training quantization.
