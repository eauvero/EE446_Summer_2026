# %%
import sys
#!{sys.executable} -m pip install -q "tensorflow==2.15.1" "tensorflow-model-optimization==0.8.0" "scikit-learn==1.4.2" "pandas==2.2.2" "matplotlib==3.8.4"

# !pip install tensorflow-model-optimization
print("Packages Installed")
# Out:
# Collecting tensorflow-model-optimization
#   Downloading tensorflow_model_optimization-0.8.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (2.0.2)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.16.3)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (0.1.10)
# Collecting mock (from tensorflow-model-optimization)
#   Downloading mock-5.2.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (26.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (2.2.2)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /usr/local/lib/python3.12/dist-packages (from tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (4.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (1.82.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.1.2)
# Downloading tensorflow_model_optimization-0.8.1-py2.py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 7.6 MB/s eta 0:00:00
# Downloading mock-5.2.0-py3-none-any.whl (31 kB)
# Installing collected packages: mock, tensorflow-model-optimization
# Successfully installed mock-5.2.0 tensorflow-model-optimization-0.8.1
# Packages Installed

# %%
import os
import math
import zipfile
import random
import urllib.request
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_model_optimization as tfmot

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow import keras
from tensorflow.keras import layers

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("Python executable:", os.sys.executable)
print("TensorFlow version:", tf.__version__)
print("TF-MOT version:", tfmot.__version__)
# Out:
# Python executable: /usr/bin/python3
# TensorFlow version: 2.20.0
# TF-MOT version: 0.8.1

# %%
from google.colab import drive
import zipfile
import os
import shutil # Import shutil for directory operations

mount_point = '/content/drive'

# --- Robust Mounting Logic ---
if os.path.exists(mount_point):
    if os.path.isdir(mount_point):
        # Check if the directory is not empty and is NOT currently a mounted filesystem
        # (i.e., it might contain leftover files that are not part of an active mount)
        if os.listdir(mount_point) and not os.path.ismount(mount_point):
            print(f"Mount point '{mount_point}' exists and is not empty. Clearing contents before mounting...")
            for item in os.listdir(mount_point):
                item_path = os.path.join(mount_point, item)
                try:
                    if os.path.isfile(item_path) or os.path.islink(item_path):
                        os.remove(item_path)
                    elif os.path.isdir(item_path):
                        shutil.rmtree(item_path)
                except Exception as e:
                    print(f"Warning: Could not fully clean {item_path}: {e}")
            print(f"Contents of '{mount_point}' cleared.")
        elif os.path.ismount(mount_point):
            print("Google Drive is already mounted and appears clean. Proceeding with remount (if needed).")
        else: # Directory exists and is empty
            print(f"Mount point '{mount_point}' exists and is empty. Proceeding.")
    else: # /content/drive exists but is not a directory (e.g., a file or broken symlink)
        print(f"Warning: '{mount_point}' exists but is not a directory. Removing and recreating it.")
        os.remove(mount_point) # Remove the non-directory item
        os.makedirs(mount_point)
else: # /content/drive does not exist
    os.makedirs(mount_point)
    print(f"Mount point '{mount_point}' created.")

print("Attempting to mount Google Drive...")
# force_remount=True will handle cases where it was previously mounted by Colab
# and will re-attempt to mount even if the directory was empty before.
drive.mount(mount_point, force_remount=True)
# --- End of Robust Mounting Logic ---

zip_path = '/content/drive/MyDrive/KaggleGazeCapture/eye_gaze_train_lsr.zip'
extract_path = '/content/eye_gaze_train_lsr/'

# Check if the extract_path does not exist or is empty
if not os.path.exists(extract_path) or not os.listdir(extract_path):
    print(f"Dataset not found locally or is empty. Extracting from Drive...")
    os.makedirs(extract_path, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("Extraction complete!")
    # Verification after extraction
    if os.path.exists(extract_path) and os.listdir(extract_path):
        print(f"Verification: '{extract_path}' exists and contains {len(os.listdir(extract_path))} items.")
    else:
        print(f"Verification: Extraction seems to have failed. '{extract_path}' is either missing or empty.")
else:
    print("Dataset directory already exists and contains data.")
    # Verification if directory already exists and contains data
    if os.path.exists(extract_path) and os.listdir(extract_path):
        print(f"Verification: '{extract_path}' already exists and contains {len(os.listdir(extract_path))} items.")
    else:
        print(f"Verification: '{extract_path}' exists but is empty. This condition should not be reached with the updated logic, but checking just in case.")
# Out:
# Mount point '/content/drive' created.
# Attempting to mount Google Drive...
# Mounted at /content/drive
# Dataset not found locally or is empty. Extracting from Drive...
# Extraction complete!
# Verification: '/content/eye_gaze_train_lsr/' exists and contains 2 items.

# %%
IMAGE_SIZE = 64
BATCH_SIZE = 32
ALPHA = 0.05

train_dir = extract_path + '/eye_gaze_train_lsr/train/'
test_dir = extract_path + '/eye_gaze_train_lsr/test/'


train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    color_mode='grayscale',
    interpolation='lanczos3',
    batch_size=None # Load unbatched images initially
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    shuffle=False,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    color_mode='grayscale',
    interpolation='lanczos3',
    batch_size=None # Load unbatched images initially
)
# Out:
# Found 173886 files belonging to 3 classes.
# Found 32233 files belonging to 3 classes.

# %%
# 1. Check tensor shapes and data types
print("--- Dataset Element Specifications ---")
print("Train Dataset Spec:", train_dataset.element_spec)
print("Test Dataset Spec: ", test_dataset.element_spec)

# 2. Inspect class names and total counts
class_names = train_dataset.class_names
print(f"\n--- Class Information ---")
print(f"Total Classes ({len(class_names)}): {class_names}")
# Out:
# --- Dataset Element Specifications ---
# Train Dataset Spec: (TensorSpec(shape=(64, 64, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))
# Test Dataset Spec:  (TensorSpec(shape=(64, 64, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))
#
# --- Class Information ---
# Total Classes (3): ['left', 'right', 'straight']

# %%
# Function to count samples per class in a dataset
def count_samples_per_class(dataset, class_names):
    class_counts = np.zeros(len(class_names), dtype=int)
    for _, labels in dataset:
        unique_labels, counts = np.unique(labels.numpy(), return_counts=True)
        for label, count in zip(unique_labels, counts):
            class_counts[label] += count

    print("\n--- Sample Counts per Class ---")
    for i, count in enumerate(class_counts):
        print(f"Class '{class_names[i]}': {count} samples")
    return class_counts


print("\n--- Training Dataset Class Counts ---")
train_class_counts = count_samples_per_class(train_dataset, class_names)

print("\n--- Test Dataset Class Counts ---")
test_class_counts = count_samples_per_class(test_dataset, class_names)
# Out:
# --- Training Dataset Class Counts ---
#
# --- Sample Counts per Class ---
# Class 'left': 49839 samples
# Class 'right': 53019 samples
# Class 'straight': 71028 samples
#
# --- Test Dataset Class Counts ---
#
# --- Sample Counts per Class ---
# Class 'left': 8923 samples
# Class 'right': 9529 samples
# Class 'straight': 13781 samples

# %%
INPUT_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 1)

def augment_image(image, label):
    # This function now receives a single image (3-D tensor: H, W, C)
    resize_factor = tf.random.uniform([], minval=1.0, maxval=1.2, dtype=tf.float32)
    new_height = tf.cast(resize_factor * INPUT_SHAPE[0], tf.int32)
    new_width = tf.cast(resize_factor * INPUT_SHAPE[1], tf.int32)

    # tf.image.resize_with_crop_or_pad now correctly receives 3-D images
    image = tf.image.resize_with_crop_or_pad(image, new_height, new_width)

    # tf.image.random_crop now correctly receives 3-D images
    image = tf.image.random_crop(image, size=INPUT_SHAPE)

    # tf.image.random_brightness supports N-D images where N >= 3, so it works directly on 3-D
    image = tf.image.random_brightness(image, max_delta=0.2)
    return image, label

def normalize_images(image, label):
    # This function now receives a single image (3-D tensor: H, W, C)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

AUTOTUNE = tf.data.AUTOTUNE # Keep AUTOTUNE defined here

# %% [markdown]
# ### Preparing separate training and validation datasets
#
# Since `validation_split` does not work directly on `tf.data.Dataset` objects, we need to manually split our `train_dataset` into separate training and validation datasets. We'll use 80% for training and 20% for validation, matching the `validation_split=0.2` you intended.

# %% [markdown]
# Now, let's apply the augmentation to the training dataset. It's important to apply augmentation only to the training set, not the validation or test sets, to avoid data leakage and ensure a realistic evaluation of the model's performance on unseen data.

# %%
# Determine the total number of samples from the unbatched training dataset
DATASET_SIZE = tf.data.experimental.cardinality(train_dataset).numpy()
val_size_samples = int(0.2 * DATASET_SIZE) # 20% for validation, in terms of samples

# Split the unbatched train_dataset into unbatched training and validation sets
val_ds_unbatched = train_dataset.take(val_size_samples)
train_ds_unbatched = train_dataset.skip(val_size_samples)

# Apply augmentation to the UNBATCHED training dataset
train_ds_aug = train_ds_unbatched.map(augment_image, num_parallel_calls=AUTOTUNE)

# Apply normalization to all datasets (augmented training, validation, and test)
train_ds = train_ds_aug.map(normalize_images, num_parallel_calls=AUTOTUNE)
val_ds = val_ds_unbatched.map(normalize_images, num_parallel_calls=AUTOTUNE)
test_ds = test_dataset.map(normalize_images, num_parallel_calls=AUTOTUNE) # Renamed for consistency

# Batch and prefetch all final datasets for efficient training
train_ds = train_ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

print(f"Original unbatched train_dataset samples: {DATASET_SIZE}")
print(f"Validation samples: {tf.data.experimental.cardinality(val_ds_unbatched).numpy()}")
print(f"Augmented training samples: {tf.data.experimental.cardinality(train_ds_unbatched).numpy()}")

print(f"\nFinal batched training_dataset batches: {tf.data.experimental.cardinality(train_ds).numpy()}")
print(f"Final batched validation_dataset batches: {tf.data.experimental.cardinality(val_ds).numpy()}")
print(f"Final batched test_dataset batches: {tf.data.experimental.cardinality(test_ds).numpy()}")
# Out:
# Original unbatched train_dataset samples: 173886
# Validation samples: 34777
# Augmented training samples: 139109
#
# Final batched training_dataset batches: 4348
# Final batched validation_dataset batches: 1087
# Final batched test_dataset batches: 1008

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense, InputLayer, Dropout, Conv1D, Flatten, Reshape, MaxPooling1D, BatchNormalization,
    Conv2D, GlobalMaxPooling2D, Lambda, GlobalAveragePooling2D)
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.losses import categorical_crossentropy

WEIGHT_PATH = '/content/drive/MyDrive/KaggleGazeCapture/pretrained_weights/mobilenetV2_0.05_96x96_greyscale_weights.h5'


# Get the number of classes from class_names
num_classes = len(class_names)

# include_top=False -- the checkpoint at WEIGHT_PATH is almost certainly a feature-extractor-only
# checkpoint (no classification head). Without this, MobileNetV2 builds the full ImageNet head by
# default, and loading WEIGHT_PATH's weights into that mismatched architecture will likely fail.
base_model = MobileNetV2(
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 1),
    alpha=ALPHA,
    include_top=False,
    weights=WEIGHT_PATH,
)
base_model.trainable = False

# Build the head on base_model.output/.input directly, rather than wrapping base_model in a new
# Model and .add()-ing it into a Sequential -- that nests a keras.Model inside another one, which
# trains fine but will hard-crash quantize_annotate_model later if this ever goes through the same
# prune/QAT pipeline as your other notebook.
x = base_model.output  # (batch, H, W, C) spatial feature map, now that include_top=False
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.1)(x)
outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 32, 32, 8) │         72 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 32, 32, 8) │         32 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 32, 32, 8) │          0 │ bn_Conv1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 32, 32, 8) │         72 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 32, 32, 8) │         32 │ expanded_conv_de… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 32, 32, 8) │          0 │ expanded_conv_de… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 32, 32, 8) │         64 │ expanded_conv_de… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 32, 32, 8) │         32 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 32, 32, 8) │          0 │ Conv1_relu[0][0], │
# │ (Add)               │                   │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 32, 32,    │        384 │ expanded_conv_ad… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 32, 32,    │        192 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 32, 32,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 33, 33,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 16, 16,    │        432 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 16, 16,    │        192 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 16, 16,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 16, 16, 8) │        384 │ block_1_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 16, 16, 8) │         32 │ block_1_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 16, 16,    │        384 │ block_1_project_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 16, 16,    │        192 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 16, 16,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 16, 16,    │        432 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 16, 16,    │        192 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 16, 16,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 16, 16, 8) │        384 │ block_2_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 16, 16, 8) │         32 │ block_2_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 16, 16, 8) │          0 │ block_1_project_… │
# │                     │                   │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 16, 16,    │        384 │ block_2_add[0][0] │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 16, 16,    │        192 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 16, 16,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 17, 17,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 8, 8, 48)  │        432 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 8, 8, 48)  │        192 │ block_3_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 8, 8, 48)  │          0 │ block_3_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 8, 8, 8)   │        384 │ block_3_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 8, 8, 8)   │         32 │ block_3_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 8, 8, 48)  │        384 │ block_3_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 8, 8, 48)  │        192 │ block_4_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 8, 8, 48)  │          0 │ block_4_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 8, 8, 48)  │        432 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 8, 8, 48)  │        192 │ block_4_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 8, 8, 48)  │          0 │ block_4_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 8, 8, 8)   │        384 │ block_4_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 8, 8, 8)   │         32 │ block_4_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 8, 8, 8)   │          0 │ block_3_project_… │
# │                     │                   │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 8, 8, 48)  │        384 │ block_4_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 8, 8, 48)  │        192 │ block_5_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 8, 8, 48)  │          0 │ block_5_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 8, 8, 48)  │        432 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 8, 8, 48)  │        192 │ block_5_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 8, 8, 48)  │          0 │ block_5_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 8, 8, 8)   │        384 │ block_5_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 8, 8, 8)   │         32 │ block_5_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 8, 8, 8)   │          0 │ block_4_add[0][0… │
# │                     │                   │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 8, 8, 48)  │        384 │ block_5_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 8, 8, 48)  │        192 │ block_6_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 8, 8, 48)  │          0 │ block_6_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 9, 9, 48)  │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 4, 4, 48)  │        432 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 4, 4, 48)  │        192 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 4, 4, 48)  │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 4, 4, 8)   │        384 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 4, 4, 8)   │         32 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 4, 4, 48)  │        384 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 4, 4, 48)  │        192 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 4, 4, 48)  │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 4, 4, 48)  │        432 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 4, 4, 48)  │        192 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 4, 4, 48)  │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 4, 4, 8)   │        384 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 4, 4, 8)   │         32 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 4, 4, 8)   │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 4, 4, 48)  │        384 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 4, 4, 48)  │        192 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 4, 4, 48)  │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 4, 4, 48)  │        432 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 4, 4, 48)  │        192 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 4, 4, 48)  │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 4, 4, 8)   │        384 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 4, 4, 8)   │         32 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 4, 4, 8)   │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 4, 4, 48)  │        384 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 4, 4, 48)  │        192 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 4, 4, 48)  │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 4, 4, 48)  │        432 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 4, 4, 48)  │        192 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 4, 4, 48)  │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 4, 4, 8)   │        384 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 4, 4, 8)   │         32 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 4, 4, 8)   │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 4, 4, 48)  │        384 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 4, 4, 48)  │        192 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 4, 4, 48)  │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 4, 4, 48)  │        432 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 4, 4, 48)  │        192 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 4, 4, 48)  │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 4, 4, 8)   │        384 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 4, 4, 8)   │         32 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_add (Add)  │ (None, 4, 4, 8)   │          0 │ block_9_add[0][0… │
# │                     │                   │            │ block_10_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 4, 4, 48)  │        384 │ block_10_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 4, 4, 48)  │        192 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 4, 4, 48)  │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 4, 4, 48)  │        432 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 4, 4, 48)  │        192 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 4, 4, 48)  │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 4, 4, 8)   │        384 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 4, 4, 8)   │         32 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 4, 4, 8)   │          0 │ block_10_add[0][… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 4, 4, 48)  │        384 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 4, 4, 48)  │        192 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 4, 4, 48)  │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 4, 4, 48)  │        432 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 4, 4, 48)  │        192 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 4, 4, 48)  │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 4, 4, 8)   │        384 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 4, 4, 8)   │         32 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 4, 4, 8)   │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 4, 4, 48)  │        384 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 4, 4, 48)  │        192 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 4, 4, 48)  │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 5, 5, 48)  │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 2, 2, 48)  │        432 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 2, 2, 48)  │        192 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 2, 2, 48)  │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 2, 2, 8)   │        384 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 2, 2, 8)   │         32 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 2, 2, 48)  │        384 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 2, 2, 48)  │        192 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 2, 2, 48)  │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 2, 2, 48)  │        432 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 2, 2, 48)  │        192 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 2, 2, 48)  │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 2, 2, 8)   │        384 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 2, 2, 8)   │         32 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 2, 2, 8)   │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 2, 2, 48)  │        384 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 2, 2, 48)  │        192 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 2, 2, 48)  │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 2, 2, 48)  │        432 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 2, 2, 48)  │        192 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 2, 2, 48)  │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 2, 2, 8)   │        384 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 2, 2, 8)   │         32 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 2, 2, 8)   │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 2, 2, 48)  │        384 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 2, 2, 48)  │        192 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 2, 2, 48)  │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 2, 2, 48)  │        432 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 2, 2, 48)  │        192 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 2, 2, 48)  │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 2, 2, 16)  │        768 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 2, 2, 16)  │         64 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 2, 2,      │     20,480 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 2, 2,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 2, 2,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │        387 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 216,531 (845.82 KB)
#  Trainable params: 164,355 (642.01 KB)
#  Non-trainable params: 52,176 (203.81 KB)

# %%
model.compile(
    optimizer="adam",
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=5,
        restore_best_weights=True
    )
]


# Train the model
# You might want to adjust epochs based on dataset size and convergence
history = model.fit(
    train_ds, # Use the new training dataset
    epochs=40,
    validation_data=val_ds, # Pass the separate validation dataset
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 252s 48ms/step - accuracy: 0.4216 - loss: 1.0682 - val_accuracy: 0.4510 - val_loss: 1.0570
# Epoch 2/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 209s 42ms/step - accuracy: 0.4445 - loss: 1.0509 - val_accuracy: 0.4646 - val_loss: 1.0384
# Epoch 3/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 260s 42ms/step - accuracy: 0.4531 - loss: 1.0415 - val_accuracy: 0.4727 - val_loss: 1.0329
# Epoch 4/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 207s 42ms/step - accuracy: 0.4625 - loss: 1.0348 - val_accuracy: 0.4783 - val_loss: 1.0263
# Epoch 5/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 209s 42ms/step - accuracy: 0.4627 - loss: 1.0316 - val_accuracy: 0.4916 - val_loss: 1.0110
# Epoch 6/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 204s 42ms/step - accuracy: 0.4659 - loss: 1.0274 - val_accuracy: 0.4910 - val_loss: 1.0126
# Epoch 7/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 220s 45ms/step - accuracy: 0.4692 - loss: 1.0234 - val_accuracy: 0.4733 - val_loss: 1.0222
# Epoch 8/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 208s 42ms/step - accuracy: 0.4714 - loss: 1.0202 - val_accuracy: 0.4862 - val_loss: 1.0136
# Epoch 9/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 211s 43ms/step - accuracy: 0.4750 - loss: 1.0166 - val_accuracy: 0.4911 - val_loss: 1.0037
# Epoch 10/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 259s 42ms/step - accuracy: 0.4750 - loss: 1.0156 - val_accuracy: 0.5016 - val_loss: 1.0023
# Epoch 11/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 222s 45ms/step - accuracy: 0.4760 - loss: 1.0129 - val_accuracy: 0.4961 - val_loss: 0.9942
# Epoch 12/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 203s 41ms/step - accuracy: 0.4803 - loss: 1.0095 - val_accuracy: 0.5028 - val_loss: 0.9879
# Epoch 13/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 199s 40ms/step - accuracy: 0.4791 - loss: 1.0088 - val_accuracy: 0.5013 - val_loss: 0.9918
# Epoch 14/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 187s 37ms/step - accuracy: 0.4790 - loss: 1.0094 - val_accuracy: 0.5117 - val_loss: 0.9894
# Epoch 15/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 187s 38ms/step - accuracy: 0.4815 - loss: 1.0060 - val_accuracy: 0.5111 - val_loss: 0.9829
# Epoch 16/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 213s 40ms/step - accuracy: 0.4811 - loss: 1.0050 - val_accuracy: 0.4783 - val_loss: 1.0026
# Epoch 17/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 190s 38ms/step - accuracy: 0.4852 - loss: 1.0031 - val_accuracy: 0.5175 - val_loss: 0.9766
# Epoch 18/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 188s 38ms/step - accuracy: 0.4847 - loss: 1.0032 - val_accuracy: 0.5062 - val_loss: 0.9962
# Epoch 19/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 187s 38ms/step - accuracy: 0.4882 - loss: 0.9999 - val_accuracy: 0.5109 - val_loss: 0.9740
# Epoch 20/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 189s 38ms/step - accuracy: 0.4885 - loss: 0.9999 - val_accuracy: 0.5170 - val_loss: 0.9836
# Epoch 21/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 189s 38ms/step - accuracy: 0.4856 - loss: 0.9997 - val_accuracy: 0.5207 - val_loss: 0.9775
# Epoch 22/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 193s 39ms/step - accuracy: 0.4875 - loss: 0.9970 - val_accuracy: 0.5128 - val_loss: 0.9806
# Epoch 23/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 187s 38ms/step - accuracy: 0.4905 - loss: 0.9972 - val_accuracy: 0.5200 - val_loss: 0.9647
# Epoch 24/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 186s 38ms/step - accuracy: 0.4899 - loss: 0.9964 - val_accuracy: 0.5201 - val_loss: 0.9786
# Epoch 25/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 185s 37ms/step - accuracy: 0.4941 - loss: 0.9935 - val_accuracy: 0.5151 - val_loss: 0.9733
# Epoch 26/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 198s 40ms/step - accuracy: 0.4913 - loss: 0.9939 - val_accuracy: 0.5292 - val_loss: 0.9710
# Epoch 27/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 188s 38ms/step - accuracy: 0.4949 - loss: 0.9905 - val_accuracy: 0.5281 - val_loss: 0.9611
# Epoch 28/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 199s 37ms/step - accuracy: 0.4925 - loss: 0.9923 - val_accuracy: 0.5224 - val_loss: 0.9675
# Epoch 29/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 197s 40ms/step - accuracy: 0.4959 - loss: 0.9890 - val_accuracy: 0.5213 - val_loss: 0.9714
# Epoch 30/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 199s 40ms/step - accuracy: 0.4936 - loss: 0.9904 - val_accuracy: 0.5278 - val_loss: 0.9541
# Epoch 31/40
# 4348/4348 ━━━━━━━━━━━━━━━━━━━━ 187s 38ms/step - accuracy: 0.4960 - loss: 0.9876 - val_accuracy: 0.5032 - val_loss: 0.9842

# %%
import matplotlib.pyplot as plt

# Plot training history (accuracy and loss)
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.show()

# %%
import numpy as np

# Extract all images and labels from the test_dataset
all_test_images = []
all_test_labels = []

for images, labels in test_ds:
    all_test_images.append(images.numpy())
    all_test_labels.append(labels.numpy())

X_test = np.vstack(all_test_images)
y_test = np.concatenate(all_test_labels)

print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_test: (32233, 64, 64, 1)
# Shape of y_test: (32233,)

# %%
# X_test will now be correctly shaped, so no explicit reshape is needed here.
# Make predictions on the extracted test data
probs = model.predict(X_test, verbose=1)
preds = np.argmax(probs, axis=1)

# Calculate accuracy
test_acc = accuracy_score(y_test, preds)

print(f"\nTest Accuracy: {test_acc:.4f}\n")

# Generate and print classification report
print("Classification Report:")
print(classification_report(y_test, preds, target_names=class_names, digits=4))

# Plot confusion matrix
disp = ConfusionMatrixDisplay(
    confusion_matrix=confusion_matrix(y_test, preds),
    display_labels=class_names
)

fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, xticks_rotation=45, cmap="Blues", colorbar=False)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 1008/1008 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step
#
# Test Accuracy: 0.3940
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         left     0.3475    0.3465    0.3470      8923
#        right     0.3520    0.6117    0.4468      9529
#     straight     0.5578    0.2742    0.3677     13781
#
#     accuracy                         0.3940     32233
#    macro avg     0.4191    0.4108    0.3872     32233
# weighted avg     0.4387    0.3940    0.3854     32233

# %%
import os

# Define the directory to save the model in Google Drive
save_dir = '/content/drive/MyDrive/saved_models'
model_name = 'transfer_eye_gaze_lsr_mobilenetv2_64px_alpha005.keras'
model_path = os.path.join(save_dir, model_name)

# Create the directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Save the entire model in the TensorFlow SavedModel format
# This includes: the architecture, the weights, and the training configuration (optimizer, loss, metrics)
# For TensorFlow SavedModel format in Keras 3, use model.export()
model.save(model_path)

print(f"Model saved successfully to: {model_path}")
# Out:
# Model saved successfully to: /content/drive/MyDrive/saved_models/transfer_eye_gaze_lsr_mobilenetv2_64px_alpha005.keras

# %%
from pathlib import Path

def make_representative_data_gen(batched_dataset, max_samples=7000):
    representative_images = []
    for batch_images, _ in batched_dataset.take(max_samples // BATCH_SIZE + 1):
        for image in batch_images:
            if len(representative_images) < max_samples:
                representative_images.append(image.numpy())
            else:
                break
        if len(representative_images) >= max_samples:
            break

    def generator():
        for img in representative_images:
            sample = np.expand_dims(img, axis=0).astype(np.float32)  # add batch dim -> (1,H,W,C)
            yield [sample]

    return generator

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # no EXPERIMENTAL_SPARSITY - nothing pruned here
converter.representative_dataset = make_representative_data_gen(train_ds)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()
tflite_path = Path(f"{save_dir}/transfer_eye_gaze_lsr_mobilenetv2_64px_alpha005_ptq.tflite")
tflite_path.write_bytes(tflite_model)
print(f"Saved {tflite_path.name}: {tflite_path.stat().st_size / 1024:.2f} KB")
# Out:
# Saved artifact at '/tmp/tmpq8g558tk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   140650663901712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040759824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040761744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040761360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040759440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040759632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040761936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040762704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040762320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040760208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040761552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040763856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040764048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040761168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040760976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040765200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040766352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040766160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040765776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040766928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040765392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040768080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040768272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040767504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040765584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040767120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040766736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040766544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040767696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040769232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040768656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040768848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040769040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040767888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040770192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040769616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040768464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040770000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040769808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040769424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040765008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018768464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018768656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018767888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018767312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018769040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018769232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018768272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018768848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018769808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018767504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018769424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018769616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018767120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018770768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018770192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018770384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018770576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018767696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018771728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018771152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018771344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018771536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018768080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018772688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018772112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018772304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018772496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018770000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018773648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018773072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018773264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018770960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018774608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018774032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018774224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018774416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018771920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018775568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018774992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018775184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018775376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018772880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018776528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018775952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018776144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018776336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018773840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018777488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018776912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018777104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018777296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018774800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018778448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018777872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018778064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018778256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018775760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018779408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018778832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018779024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018779216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018776720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018780368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018779792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018779984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018780176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018777680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018781328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018780752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018780944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018781136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018778640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018782288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018781712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018781904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018781520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018783056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018782480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018780560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018782672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018782864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018782096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650018779600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029121808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029122960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029122768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029122384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029123536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029122000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029123152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029123344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029121616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029124496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029123920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029124112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029124304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029125456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029124880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029125072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029125264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029122576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029126416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029125840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029126224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029123728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029127376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029126800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029126992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029127184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029124688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029128336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029127760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029127952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029128144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029125648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029129296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029128912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029129104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029126608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029130256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029129680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029129872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029130064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029127568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029131216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029130640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029130832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029131024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029128528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029132176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029131600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029131792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029131984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029129488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029133136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029132560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029132752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029132944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029130448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029134096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029133520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029133712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029133904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029131408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029135056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029134480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029134672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029134864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029132368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029136016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029135440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029135632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029135824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029133328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029136976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029136400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029136592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029136208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029137744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029137168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029135248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029137360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029137552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029136784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650029134288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035446032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035447184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035446992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035446608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035447760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035446224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035447376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035447568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035445840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035448720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035448144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035448336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035448528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035446416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035449680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035449104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035449296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035449488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035446800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035450640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035450064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035450256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035450448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035447952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035451600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035451024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035451216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035451408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035448912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035452560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035451984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035452176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035452368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035449872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035453520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035452944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035453136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035453328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035450832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035454480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035453904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035454096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035454288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035451792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035455440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035454864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035455056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035455248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035452752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035456400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650040760016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035456592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035456976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140650035457552: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Saved transfer_eye_gaze_lsr_mobilenetv2_64px_alpha005_ptq.tflite: 320.73 KB

# %% [markdown]
# You can then load this H5 file using `tf.keras.models.load_model()` and proceed with quantization-aware training or post-training quantization.
